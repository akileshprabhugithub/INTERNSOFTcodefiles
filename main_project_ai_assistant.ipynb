# %%
#importing packages

import os
import subprocess
import time
import json
import random

# %%
import wolframalpha
import wikipedia
import requests
import webbrowser
import datetime
import re
import pyjokes
from bs4 import BeautifulSoup as soup

# %%
import speech_recognition as sr
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pyttsx3
import smtplib, ssl
import urllib.request
import urllib.parse
from urllib.request import urlopen

# %%
print('LOADING YOUR A.I PERSONAL ASSISTANT ATHENA')
# Out:
# LOADING YOUR A.I PERSONAL ASSISTANT ATHENA

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty("voice",voices[1].id)

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def wishMe():
    hour = datetime.datetime.now().hour
    if hour >=0 and  hour<12:
        speak("hello, good morning Mr. Akilesh")
        print("hello, good morning Mr. Akilesh")
    elif hour >= 12 and hour <4:
        speak("hello, good afternoon Mr. Akilesh")
        print("hello, good afternoon Mr. Akilesh")
    elif hour >= 4 and hour <19:
        speak("hello, good evening Mr. Akilesh")
        print("hello, good evening Mr. Akilesh")
    else:
        speak("its about time you had some sleep")
        print("its about time you had some sleep")

# %%
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        r.adjust_for_ambient_noise(source)
        print("i am listening")
        audio = r.listen(source)
        
        try:
            statement = r.recognize_google(audio,language='en-in')
            print(f"user said : {statement}\n")
            
        except Exception as e:
            speak("pardon me, please repeat that again")
            return "None"
        return statement

# %%
speak("loading your personal ai assistant athena")
wishMe()
# Out:
# its about time you had some sleep

# %%
if __name__ == '__main__':
    while True:
        
        speak("how can i help you ?")
        statement =  takeCommand().lower()
        if statement == 0:
            continue
        if "good bye" in statement or "ok bye" in statement or "stop" in statement or "thank you for your service" in statement:
            speak("your personal ai assistant athena shutting down, good bye")
            print("your personal ai assistant athena shutting down, good bye")
            break
        if "wikipedia" in statement:
            speak("searching wikipedia....")
            statement = statement.replace('wikipedia', " ")
            results = wikipedia.summary(statement, sentences = 3)
            speak("according to wikipedia....")
            print(results)
            speak(results)
        
        elif "open google" in statement:
            webbrowser.open_new_tab("https://www.google.com")
            speak("opening google search...")
            time.sleep(5)
            
        elif "open gmail" in statement:
            webbrowser.open_new_tab("https://www.gmail.com")
            speak("opening gmail...")
            time.sleep(5)
        
        elif "weather" in statement:
            api_key ="8ef61edcf1c576d65d836254e11ea420"
            base_url ="https://api.openweathermap.org/data/2.5/weather?"
            speak("whats your city name")
            city_name = takeCommand()
            complete_url = base_url+"appid="+api_key+"&q="+city_name
            response = requests.get(complete_url)
            x = response.json()
            print(x)
            if x["cod"] != "404":
                y = x["main"]
                current_temperature = y["temp"]
                current_humidity = y["humidity"]
                z = x["weather"]
                weather_description = z[0]["description"]
                speak("temperature in kelvin units is:" + str(current_temperature) +"\n humidity in percentage is :" + str(current_humidity) + "\n weather description" + str(weather_description))
                print("temperature in kelvin units is:" + str(current_temperature) +"\n humidity in percentage is :" + str(current_humidity) + "\n weather description" + str(weather_description))
            
            else:
                speak("city not found")
                print("city not found")
            
        elif "time" in statement:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"the time is :{strTime}")
            
        elif "who are you" in statement or "what can you do" in statement:
            speak("i am athena version 1 point 0 your personal assistant. i am programmed to assist you in your day-to-day minor tasks. some of my general tasks include greeting you, opening youtube videos, google chrome, gmail, taking notes, fetching you news headlines, sending an email and providing you weather forecast for the day")
            
        elif "who made you" in statement or "who created you" in statement or "who built you" in statement:
            speak("i was built by narendra modi") #pun intended
            print("i was built by narendra modi")
            
        elif "what's up" in statement or "how are you" in statement or "what are you doing" in statement :
            setReplies = ["just doing some stuff!", "i am good", " nothing much, i am alright. thanks for asking", "just wondering when are we gonna take over the world"]
            speak(random.choice(setReplies))
    
        elif "open stack overflow" in statement:
            webbrowser.open_new_tab("https://stackoverflow.com/login")
            time.sleep(5)
            
        elif 'news update' in statement:              
            try:
                news_url="https://news.google.com/news/rss"
                Client=urlopen(news_url)
                xml_page=Client.read()
                Client.close()
                soup_page=soup(xml_page,"xml")
                news_list=soup_page.findAll("item")
                speak("here are some news headlines for you from google ")
                
                for news in news_list[:10]:
                    print(news.title.text)
                    speak(news.title.text)
                    print(news.link.text)
                    print(news.pubDate.text)
                    print("-"*60)
                    time.sleep(5)
                    
            except Exception as e: 
                  print(str(e))
         
        elif "search for" in statement:
            statement  =  statement.replace("search for"," ")
            webbrowser.open_new_tab("https://duckduckgo.com/?q= " + statement  )
            time.sleep(5)
            
        elif "send mail" in statement :
            speak("what is the subject?")
            subject = takeCommand().lower()
            print(subject)
            s = subject.split()
            if 'cancel' or "abort" not in s:
                try:
                    speak("what should i say?")
                    message = takeCommand()
                    content = "Subject: {}\n\n{}".format(subject,message)
                    server = smtplib.SMTP('smtp.gmail.com', 587)
                    server.ehlo()
                    server.starttls()
                    server.login("sender@gmail.com", '123password')
                    server.sendmail('sender@gmail.com', "receiver@gmail.com", content)
                    server.close()
                    speak('Email sent!')
                    print('Email sent!')
                except:
                    speak('Sorry ! I am unable to send your message at this moment!')
                    print('Sorry ! I am unable to send your message at this moment!')
                
        elif "where is" in statement:
            speak("opening google maps")
            statement = statement.replace("where is", "")
            location = statement
            speak("locating...." + location)
            print("locating...." + location)
            webbrowser.open("https://www.google.com/maps/place/" + location + "")
            time.sleep(5)
                    
        elif 'on youtube' in statement:
            statement = statement.replace("open","")
            statement = statement.replace("on youtube","")
            webbrowser.open_new_tab("https://www.youtube.com/results?search_query="+ statement.strip())
            speak('searching on youtube')
            time.sleep(5)
            
        elif "write a note" in statement or "take a note" in statement:
            speak("What would you like me to write, sir")
            note = takeCommand()
            file = open('athena_notes.txt', 'w')
            speak("Sir, Should i include date and time")
            statement = takeCommand().lower()
            if 'yes' in statement or 'sure' in statement:
                strTime = datetime.datetime.now().strftime("%H:%M:%S")
                file.write(strTime)
                file.write(" :- ")
                file.write(note)
                speak("saving note")
            else:
                file.write(note)
                speak("saving note")
          
        elif "show note" in statement:
            speak("Showing Notes")
            file = open("athena_notes.txt", "r")
            read = file.read()
            print(read)
            speak(read)
            time.sleep(3)
            
        elif "open main project" in statement:
            path = r"C:\Users\NEXTEL\Desktop\1 p\code files\main project\main_project_1.ipynb"
            os.startfile(path)
            speak("opening main project")
            
        elif "joke" in statement:
            joke = pyjokes.get_joke()
            print(joke)
            speak(joke)
               
        elif "ask" in statement :
            speak("i can answer to computational and geographical questions too just try me!! what do you want to ask")
            question = takeCommand()
            app_id="R2K75H-7ELALHR35X"
            client = wolframalpha.Client('R2K75H-7ELALHR35X')
            res = client.query(question)
            answer = next(res.results).text
            speak(answer)
            print(answer)
            
        elif "log off" in statement or "sign off" in statement or "shut down" in statement:
            speak("okay, your pc will shut down in 10 seconds - make sure you have saved and exited from all applications ")
            subprocess.call(['shutdown', "/1"])
time.sleep(3)
# Out:
# i am listening
# user said : who are you
#
# i am listening
# user said : who made you
#
# i was built by narendra modi
# i am listening
# user said : how are you
#
# i am listening
# user said : open Google
#
# i am listening
# user said : Gmail
#
# i am listening
# user said : open Gmail
#
# i am listening
# user said : Kobe Bryant on Wikipedia
#
# ...
